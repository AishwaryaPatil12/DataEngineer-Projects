# %% [markdown]
# ##Create Catalog and Schema

# %%
# %sql
create catalog if not exists lakehouse;

# %%
# %sql
use catalog lakehouse;
    
create schema if not exists bronze;
create schema if not exists silver;
create schema if not exists gold;

# %%
# %sql
use schema bronze; --using bronze schema to load the data in bronze layer

# %% [markdown]
# ##Load raw CSV file into Bronze table

# %%
from pyspark.sql import functions as F

#load cvs file
df_bronze = spark.read.csv(
    "/Volumes/lakehouse/bronze/rawfiles/sales_data.csv.csv",
    header=True,
    inferSchema=True
)

#display the loaded data
display(df_bronze)

#save data in bronze table
df_bronze.write.mode("overwrite").saveAsTable("lakehouse.bronze.sales_bronze")
